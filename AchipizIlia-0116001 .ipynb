# %%
#ejercicio 1 
numero=int(input( "ingrese un número:"))
if numero<0:
    print(" el numero es: negativo")
else:
    print("el numero es:", numero)

while numero <0:
    numero=numero*-1
    print (" su valor absoluto es:", numero)

# %%
#%% EJERCICIO 2
#Leer un número entero y escribirlo en reversa
    
a = (input("ingrese un número:"))
cadena=a
print  (cadena[::-1])
# Out:
# ingrese un número:3456
# 6543

# %%
#%% EJERCICIO 3
# Leer un número entero de 3 dígitos y determinar si contiene el dígito 8.


num=(input(" escriba un numero de tres dijitos"))

bandera=0
    
for i in num:
        if i== "8":
            bandera=1
if bandera ==0:
    print("el numero no contiene un numero 8")
else:
    print("el número tiene al menos un 8")

# %%
#%% EJERCICIO 4
#Leer un número entero positivo y determinar la suma de sus dígitos pares.
sum=0
num=int(input("Ingrese un número"))
while(num>1):
 digito=int(num%10)
 num=num/10
 if(digito%2==0):
  sum=sum+digito
print(sum)

# %%
# EJERCICIO 7
#Leer un número entero positivo y determine si existen en el número dígitos repetidos.

valores =input("escriba un  número:")
repetido = []
unico=[]
 
for i in valores:
    if i not in unico:
        unico.append(i)
    else:
        if i not in repetido:
        repetido.append(i)
print (" los valores  repetidos son:",repetido)

# %%
#%% EJERCICIO 8

#Iterar a través de los primeros cien enteros positivos, buscando los múltiplosde 3 e imprimiendo y almacenándolos en una
#lista hasta encontrar los primeros 15 de ellos. Una vez encontrados, continuar iterando en busca delos 
#múltiplosde 4 y almacenarlos en otra lista.

contador=0
print('Multiplos de 3:') 
for i in range(101):
    if (i//3)*3==i and i!=0:
        print(i)
        contador+=1
        if contador==15:
            break
print('multiplos de 4')
for s in range(i,101):
    if (s//4)*4==s:
       print(s)

# %%
#%% EJERCICIO 9 
#Hacer un programa que lea las coordenadas (x1,y1,r1) y (x2,y2,r2)
# que corresponden al centro y al radio de dos círculos.


print("escriba las coordenadas  y radio del primer circulo ")
x1=int(input("abscisa 1:"))
y1=int(input("ordenada 1:"))
r1=int(input("radio 1:"))

print("escriba las coordenadas  y radio del segundo circulo ")
x2=int(input("abscisa 2:"))
y2=int(input("ordenada 2:"))
r2=int(input("radio 2:"))

#Lea un punto de coordenadas (a,b).
a=int(input("escriba  la abscisa:" ))
b=int(input("escriba la ordenada:"))

#Determina si (a,b) está contenido: a) dentro del círculo 1; 
#b) dentro del círculo 2;c) dentro de ambos círculos; d) fuera de ambos círculos.

if (a-x1)**2 +(b-y1)**2 <r1**2 and (a-x2)**2 +(b-y2)**2 <r2**2:
    print ("la coordenadas dada esta dentro del circulo 1 y 2")
    
elif (a-x1)**2 +(b-y1)**2 <r1**2:
    print("las coordenadas esta dentro del primer circulo")

elif (a-x2)**2 +(b-y2)**2 <r2**2:
    print("la coordenada esta dentro del segundo circulo")
    
if (a-x1)**2 +(b-y1)**2 >=r1**2 and (a-x2)**2 +(b-y2)**2 >=r2**2:
    print("la coordenada no esta en  ninguno de los dos circulos")

# %%
#%% EJERCICIO 10
#un programa que lea una cadena de texto y la imprima en mayusculas
#el programa debe aceptar las letras con tilde, la ñ y la ü.


a="¿hola cómo estas?"
m=['a','á','b','c','d','e','é','f','g','h','i','í','j','k','l','m','n','ñ',\
   'o','ó','p','q','r','s','t','u','ú','ü','v','w','x','y','z','¿','?']
M=['A','Á','B','C','D','E','É','F','G','H','I','Í','J','K','L','M','N','Ñ',\
   'O','Ó','P','Q','R','S','T','U','Ú','Ü','V','W','X','Y','Z','¿','?']
s=[]
for i in range(len(a)):
    if a[i]==' ':
        s.append(' ')
    else:
        for j in range(len(m)):
            if a[i]==m[j]:
                s.append(M[j])
print("El texto en mayusculas es"," ".join(s))

# %%
#%%EJERCICIO 11
#Escribir un programa que reciba una cadena de texto y reporte:a) cuántas letras vocales en mayúscula se entraron;b) cuántas 
#letras con tilde se entraron (minúsculas y mayúsculas);c) cuántos dígitos se entraron,d) cuántos espacios se entraron;e) cuántas palabras reservadas se entraron.
 
import keyword
texto= input("escriba una palabra")
M="AEIOUÁÉÍÓÚ"
S1=[]
for i in range(0, len(texto)):
    if texto[i] in M:
        S1.append(texto[i])
print ("tiene", len(S1),"vocales mayusculas")

MT="ÁÉÍÓÚáéíóú"
S2=[]
for i in range(0, len(texto)):
    if texto[i] in MT:
        S2.append(texto[i])
print ("tiene", len(S2),"vocales con tilde")

num="0123456789"
S3=[]
for i in range(0, len(texto)):
    if texto[i] in num:
        S3.append(texto[i])
print ("tiene", len(S3),"digitos")


espacio= " "
S4=[]
for i in range(0, len(texto)):
    if texto[i] in espacio:
        S4.append(texto[i])
print ("tiene", len(S4),"espacios")

S5=texto.split()
S6=[]
for i in range(0, len(S5)):
    if [i] in keyword.kwlist:
        S6.append(S5[i])
print (S6,"son keywords contenidas en la palabra digitada")

# %%
#%% EJERCICIO 15
#Leer una lista de números enteros y enumerar cuantos elementos se repiten
 #exactamente dos veces. Utilizar para tal fin el método count() de listas. 
 
m=input("dijite una lista:") #lista
c=[]            #vacio para guardar las veces que se repite cada número
n=[]            #vacio para guardar los nuúmeros que ya fueron contados
x=[]            #vacio para guardar los números que se repiten 2 veces
for i in range(len(m)):
    if m[i] in n:
        i=i+1
    else:
        v=m.count(m[i])  #cuantas veces esta el número en la lista
        a=m[i]          #numero que ya se conto
        if v==2:
            x.append(m[i])
        c.append(v)      #guarda las veces que se repite el número
        n.append(m[i])  #guarda en n el número que ya se conto

print(c)    
g=c.count(2)   #cuenta cuantos elementos se repiten dos veces
print("Hay %s elementos que se repiten dos veces y son: " %g, x)

# %%
#%% EJERCICIO 16
#Leer una lista de números ya ordenados de forma ascendente y verificar que dicha lista está ordenada. Luego, leer un número
#e insertarlo en la lista en la posición que le corresponde a dicho número.
 
 
c=input('inserte lista:')  #leemos la lista, se deben ingresar los numeros sin 
                          #espacion ni comillas, ni corchetes.

a=[]                  #para guardr la lista

for i in range(len(c)):   
    a.append(int(c[i]))    #creamos la lista con los numeros ingresados arriba

for j in range(len(a)-1):  #comprobamos que la lista esta ordenada
    if a[j]<a[j+1]:
        t=True
    elif a[j]>a[j+1]:
        t=False
        
if t is True:
    print("La lista esta ordenada")  #si la lista esta ordenda,
    #puede ingresar nuevo numero
    b=int(input('inserte numero:'))
    for i in range(len(a)-1):      
        if b>a[i] and b<a[i+1]:   #agregamos el numero a la lista
            a.append(b)
 
    a=sorted(a)    #ordenamos la lista
    print(a)      #se muestra la lista final
    
elif t is False:
    print("La lista no esta ordenada")     #Si la lista que se ingreso no
    #esta ordenada

# %%
#%%EJERCICIO 17
#Leer una lista y determinar cuál es el segundo elemento
# más grande de dicha lista

#a=[5, 6, 5, 1, 2, 6, 5, 2, 9, 1]
c=input('inserte lista:')  #leemos la lista, se deben ingresar los numeros sin 
                          #espacion ni comillas, ni corchetes.

a=[]                  #para guardr la lista

for i in range(len(c)):   
    a.append(int(c[i]))  #creamos la lista con los numeros ingresados arriba

m=max(a)                #Encontramos el numero maximo de la lista m
n=a[0]
for i in range(len(a)):
    if a[i]>n and a[i]!= m:   #Encontramos el maximo numero de la lista que no
        #sea m
        n=a[i]                  #guarda en n el segundo numero mas grande
           
print("El segundo numero mayor es:",(n))

# %%
#%% EJERCICIO 18
#Leer una matriz cuadrada A, obtener su matriz triangular superior asociada U y determinar qué fila de U contiene la
#mayor cantidad de unos.

import numpy as np
#A=[[1,42,1,66],[10,1,92,1],[37,1,1,19],[1,72,1,1]] 
n=input('inserte numero de filas y columnas:')#se ingresa # de filas y columnas de A
n=int(n)

A=mn=np.zeros((n,n),int)#Matriz de ceros para guardar en A los valores ingreados 

a=[]
for i in range(n):
    c=input('Ingrese los {:-1} valores de la fila {:-1}:'.format(n, i)) #Insertar filas de A ,
    for j in range(len(c)):   #numero sin comillas, comas, puntos etc.
        
        A[i][j]=int(c[j])                   #Agregamos a A cada fila
                                          #para guardr la list
print(A)   #Mostrar A


U=np.triu(A)    #Matriz triangular usando Numpy
print("La matriz triangular superior es")
for i in range(len(U)):   #Mostrar U de A
    print(U[i])
    
fu=[]  #para guardar las filas donde hay unos
c=0     #contador en cero, incrementa cuando hay un 1
t=False #suponemos que no hay 1 
for i in range(len(U)):
    for j in range(len(U)):
        if U[i][j]==1:  
            c=c+1      
            t=True #si hay 1 t = True
    fu.append(c)  #se agrega a fu la cantidad de 1 en cada fila
    c=0 #cuando se contaron los 1 de cada fila, se reinicia en contador
    #para contar los unos de la fila siguiente.


if t is True:                    #Si hay unos  
    for i in range(len(fu)):     #buscamos 
        if fu[i]==max(fu):       #el maximo numero de unos
            print("La fila(s) que tiene mayor numero de unos es la fila %s:" %[i])
else:
    print("No hay unos en la fila")  #Si no hay unos

# %%
#%% EJERCICIO 19
#Leer una lista e identifique la sublista más larga dentro de dicha lista que se encuentra ordenada ascendentemente
lista= [5, 6, 5, 1, 2, 6, 9, 2, 4, 1]

sublista=[]
s=[]
sublista.append(lista[0])
c=0
for i in range(len(lista)-1):
    if sublista[c]<lista[i+1]:
        sublista.append(lista[i+1])
        c=c+1
        l=len(sublista)
    else:
        if len(sublista)>len(s):
            s=sublista
        c=0
        sublista=[]
        sublista.append(lista[i+1])
print("La mayor sublista ordenada es",s)

# %%
#%% EJERCICIO 20 
#Hacer un programa que lea una matriz y la rote 90 grados 
#en sentido antihorario

import numpy as np
m=[[62,42,70,66,10],[35,10,4,92,94],[33,37,5,100,19],[79,44,72,53,91 ]] 

for i in range(len(m)):
    print(m[i])
    
f=len(m)
c=len(m[0])
mn=np.zeros((c,f),int)
ff=len(mn)
cc=len(mn[0])



for i in range(f):
    k=0
    for j in range(c-1,-1,-1):
        mn[j][i]=(m[i][k])
        k=k+1
print("La Nueva Matriz es")           
for i in range(len(mn)):
    print(mn[i])     
    
#%% MODULO NUMPY
m=[[62,42,70,66,10],[35,10,4,92,94],[33,37,5,100,19],[79,44,72,53,91 ]]


    
for i in range(len(m)):
    print(m[i])
    
a=np.rot90(m)    

#NUEVA MATRIZ
print("La Nueva Matriz es")    
for i in range(len(a)):
    print(a[i])
